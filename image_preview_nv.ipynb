# %%
from matplotlib import pyplot as plt
import numpy as np
import PIL
import os
import scipy

# %%
#data_infile = open('','rb')
data_infile2 = open('FF73Ag5Mo5.36.37__d0.37m_a20um_p110um_step-4.2_dith23.25_1.raw', 'rb')
data_infile3 = np.genfromtxt('AgMo.txt')

#data_array = np.fromfile(data_infile,dtype='float32',count=256*256)
#data_image = PIL.Image.frombuffer("F",[256,256],data_array,'raw','F',0,1)

data_array2 = np.fromfile(data_infile2,dtype='float32',count=256*256)
data_image2 = PIL.Image.frombuffer("F",[256,256],data_array2,'raw','F',0,1)

plt.imshow(data_infile3)

# %%
img1 = np.array(data_infile3.getdata())
img1=img1.reshape(256,256) 

img2 = np.array(data_image2.getdata())
img2=img2.reshape(256,256) 

img3 = img1/img2

fig2=plt.figure(figsize=(12,6))
ax1=fig2.add_subplot(111)
ax1.set_xlabel('X [pixels]', fontsize=13,labelpad=15)
ax1.set_ylabel('Y [pixels]', fontsize=13,labelpad=15)
ax1.set_title('Test 28kV 1e8 events Al =0.5mm')
plt.savefig('87_Si.png')

p1= ax1.imshow(img1, cmap='bone')
cbar = fig2.colorbar(p1)
cbar.set_label('Intensity [counts]')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-aba4b5821555> in <module>
# ----> 1 img1 = np.array(data_infile3.getdata())
#       2 img1=img1.reshape(256,256)
#       3
#       4 img2 = np.array(data_image2.getdata())
#       5 img2=img2.reshape(256,256)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'getdata'

# %%
img_crop = data_infile3[100:115,40:75]
sigma = np.std(img_crop)
mean = np.mean(img_crop)
vis = sigma/mean
plt.imshow(img_crop,cmap='bone')
vis*100
# Out:
# 41.01974683873142

# %%
x_profile1 = np.mean(img_crop/mean,0)

plt.plot(x_profile1[1::])
plt.title(r'Intensity profile for Tumor mass')
plt.xlabel('X [Pixels]')
plt.ylabel('Mean Intensity [counts]')
#x_profile1.shape
x_profile1[245::]
plt.grid(linestyle ='--')

# %%
REF = np.genfromtxt('1.8e9_speckle/DATA_MIST/REF_00.txt')
SAMP = np.genfromtxt('1.8e9_speckle/DATA_MIST/SAMP_00.txt')
FF = np.genfromtxt('FF_2.txt')
IM_C = REF/FF
IM_Crop = IM_C[0:75,0:75]
plt.imshow(IM_C, cmap='bone')
plt.colorbar()

# %%
def PI(name,inicial,final,h,y):
    P=np.zeros(y-h)
    for i in range(inicial,final):
        P=P+name[i,h:y]
    mean=P/(final-inicial)
    return mean

# %%
root = scipy.ndimage.shift(img1,[0,np.pi])

# %%
plt.imshow(root)

# %%
import spekpy as sp
s =
